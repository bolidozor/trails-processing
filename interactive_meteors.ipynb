# %% [markdown]
# Trails processing
# ===================
# Moving your mouse pointer across the display below will rotate the celestial sphere,
# displaying the meteors trails over the stars from Hipparcos catalouge

# %%
path_to_csv_file = "http://meteor1.astrozor.cz:3003/expa14.csv"

# %%
# %pylab inline
import sky
import meteors
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', 10000)

# %% [markdown]
# Loading data
# ------------
# Loading data from csv table, fixing the mising observer's position, by using different observer position (if it exists) or calculating with average position from all observers

# %%
data = meteors.load_data(path_to_csv_file)
data = meteors.fix_position(data)

# %% [markdown]
# Displaying the meteor trails
# ------------------------
# First argument is pandas data structure, second argument is lowest magnitude shown. Based on [astronomy notebooks by Brandon Rhodes](https://github.com/brandon-rhodes/astronomy-notebooks) You can choose what do you want to display using [pandas features](http://pandas.pydata.org/pandas-docs/stable/cookbook.html)

# %%
sky.starfield(data, 4.5)
# Out:
# <style>
#   .constellation {fill: #dddddd}oke
#   .star-blue {fill: #002664}
#   .trails {fill: none; stroke: #000; stroke-width: 1px;}
# </style>
# <script>
# var boundary_data = {'COL':{'type':'Polygon','coordinates':[[[18000,-2580.0],[18000,-1635.0],[22020,-1635.0],[22020,-1980.0],[23700,-1980.0],[23700,-2580.0],[21600,-2580.0]]]},'CRV':{'type':'Polygon','coordinates':[[[46200,-660.0],[46200,-1320.0],[45300,-1320.0],[45300,-1470.0],[42600,-1470.0],[42600,-660.0]]]},'LYN':{'type':'Polygon','coordinates':[[[26520,2130.0],[26520,2670.0],[24480,2670.0],[24480,3000.0],[23400,3000.0],[23400,3240.0],[21960,3240.0],[21960,3360.0],[21960,3720.0],[25200,3720.0],[25200,3600.0],[28680,3600.0],[30300,3600.0],[30300,2820.0],[33000,2820.0],[33000,2520.0],[34500,2520.0],[34500,2385.0],[33300,2385.0],[33300,2010.0],[28800,2010.0],[27900,2010.0],[27900,2130.0]]]},'OCT':{'type':'Polygon','coordinates':[[[0,-4500.0],[0,-4950.0],[12600,-4950.0],[12600,-5100.0],[27600,-5100.0],[27600,-4950.0],[49200,-4950.0],[64800,-4950.0],[64800,-4500.0],[76800,-4500.0],[84000,-4500.0]]]},'LYR':{'type':'Polygon','coordinates':[[[67920,1530.0],[67920,1560.0],[66120,1560.0],[66120,1800.0],[65430,1800.0],[65430,2850.0],[65640,2850.0],[68700,2850.0],[69000,2850.0],[69000,2610.0],[69840,2610.0],[69840,2190.0],[69690,2190.0],[69690,1800.0],[69330,1800.0],[69330,1650.0],[69330,1530.0]]]},'ANT':{'type':'Polygon','coordinates':[[[33720,-1440.0],[35100,-1440.0],[35100,-1590.0],[36900,-1590.0],[36900,-1750.0],[38100,-1750.0],[38100,-1870.0],[39000,-1870.0],[39000,-2100.0],[39600,-2100.0],[39600,-2385.0],[33720,-2385.0],[33720,-2205.0]]]},'CMA':{'type':'Polygon','coordinates':[[[22020,-660.0],[26520,-660.0],[26520,-1980.0],[23700,-1980.0],[22020,-1980.0],[22020,-1635.0]]]},'TUC':{'type':'Polygon','coordinates':[[[84000,-4500.0],[84000,-4050.0],[79200,-4050.0],[79200,-3420.0],[84000,-3420.0],[84000,-3510.0],[4800,-3510.0],[4800,-4560.0],[2700,-4560.0],[2700,-4500.0],[0,-4500.0]]]},'MON':{'type':'Polygon','coordinates':[[[22470,0.0],[22470,600.0],[22710,600.0],[22710,720.0],[24960,720.0],[24960,600.0],[25200,600.0],[25200,330.0],[25260,330.0],[25260,90.0],[25920,90.0],[25920,0.0],[29100,0.0],[29100,-660.0],[26520,-660.0],[22020,-660.0],[21000,-660.0],[21000,-240.0],[22470,-240.0]]]},'LUP':{'type':'Polygon','coordinates':[[[51000,-3300.0],[51000,-2520.0],[53700,-2520.0],[53700,-1770.0],[56400,-1770.0],[57600,-1770.0],[57600,-2520.0],[56400,-2520.0],[56400,-2880.0],[55200,-2880.0],[55200,-3240.0],[54180,-3240.0],[54180,-3300.0],[52320,-3300.0]]]},'PSC':{'type':'Polygon','coordinates':[[[81900,0.0],[81900,120.0],[81900,450.0],[85800,450.0],[85800,600.0],[0,600.0],[0,750.0],[510,750.0],[510,1260.0],[3060,1260.0],[3060,1425.0],[2580,1425.0],[2580,1980.0],[5070,1980.0],[5070,1680.0],[6000,1680.0],[6000,1500.0],[6000,595.0],[7200,595.0],[7200,120.0],[1200,120.0],[1200,0.0],[1200,-420.0],[85800,-420.0],[85800,-240.0],[81900,-240.0]]]},'HYI':{'type':'Polygon','coordinates':[[[16500,-4050.0],[16500,-4200.0],[16500,-4500.0],[12600,-4500.0],[12600,-4950.0],[0,-4950.0],[0,-4500.0],[2700,-4500.0],[2700,-4560.0],[4800,-4560.0],[4800,-3510.0],[7800,-3510.0],[7800,-4050.0],[11520,-4050.0]]]},'PHE':{'type':'Polygon','coordinates':[[[84000,-2400.0],[6000,-2400.0],[8400,-2400.0],[8400,-2890.0],[6600,-2890.0],[6600,-3090.0],[5700,-3090.0],[5700,-3210.0],[4800,-3210.0],[4800,-3510.0],[84000,-3510.0],[84000,-3420.0]]]},'DEL':{'type':'Polygon','coordinates':[[[73920,120.0],[73080,120.0],[73080,510.0],[72510,510.0],[72510,945.0],[72900,945.0],[72900,1230.0],[74040,1230.0],[74040,1170.0],[75780,1170.0],[75780,710.0],[75150,710.0],[75150,360.0],[75000,360.0],[75000,120.0]]]},'LAC':{'type':'Polygon','coordinates':[[[78750,2160.0],[78750,2625.0],[78870,2625.0],[78870,2640.0],[79080,2640.0],[79080,3165.0],[79680,3165.0],[79680,3300.0],[80340,3300.0],[80340,3375.0],[82320,3375.0],[82320,3150.0],[82320,2070.0],[82140,2070.0],[82140,2100.0],[79200,2100.0],[79200,2160.0]]]},'PAV':{'type':'Polygon','coordinates':[[[64800,-4500.0],[64800,-4050.0],[63000,-4050.0],[63000,-3420.0],[64800,-3420.0],[73200,-3420.0],[73200,-3600.0],[76800,-3600.0],[76800,-4500.0]]]},'TRI': ...

# %% [markdown]
# Ploting the score board
# -----------------------
# Winner schould get chocolate

# %%
score = data.groupby("observer").observer.count()
score.sort(ascending = False)

font = {'size'   : 18}
matplotlib.rc('font', **font)
rcParams['figure.figsize'] = (18, 5)
score.plot(kind = "bar", )

# %% [markdown]
# Table of all records
# --------------------
# Time is in utc

# %%
data
# Out:
#                    time     beg_x     beg_y     beg_z     end_x     end_y  \
# 0   2014-07-17 16:37:21 -0.589888 -0.705631  0.392577 -0.247706 -0.543068
# 1   2014-07-17 16:37:28 -0.211601 -0.685614  0.696533 -0.796459  0.011668
# 2   2014-07-15 20:51:03  0.875382  0.409684  0.256643  0.486931  0.762538
# 3   2014-07-18 23:04:14 -0.736155 -0.277478  0.617318 -0.575807  0.794333
# 4   2014-07-18 23:04:25 -0.562187 -0.680422  0.470076 -0.110813 -0.987654
# 5   2014-07-18 23:05:43 -0.585938 -0.660247 -0.469840 -0.208504 -0.841034
# 6   2014-07-18 23:09:38 -0.480081  0.519489  0.706862 -0.568090  0.449296
# 7   2014-07-18 23:09:49 -0.238103  0.026114  0.970889 -0.249532  0.041908
# 8   2014-07-18 23:09:56  0.023791  0.396801  0.917596  0.006202  0.394104
# 9   2014-07-18 23:19:32 -0.119441  0.071627  0.990254 -0.174212  0.093709
# 10  2014-07-18 23:19:39 -0.536367  0.354943  0.765719 -0.555615  0.356295
# 11  2014-07-18 23:19:46  0.091953  0.302379  0.948742  0.046767  0.345869
# 12  2014-07-18 23:20:01 -0.502481  0.541624  0.673911 -0.438543  0.487822
# 13  2014-07-18 23:20:12 -0.044556  0.185240  0.981683 -0.140737  0.122985
# 14  2014-07-18 23:20:22  0.184517  0.284969  0.940609  0.163018  0.340759
# 15  2014-07-19 12:54:19  0.759278 -0.650706 -0.008876 -0.447226  0.064251
# 16  2014-07-20 01:53:11 -0.168897 -0.196156  0.965918 -0.518258 -0.008029
# 17  2014-07-20 01:54:11 -0.323576  0.495756  0.805931 -0.683826  0.483493
# 18  2014-07-20 02:36:33  0.096707  0.110179  0.989196  0.056343  0.415740
# 19  2014-07-20 03:00:18 -0.194946  0.523847  0.829205 -0.520672  0.303398
# 20  2014-07-20 03:00:34  0.246427 -0.132466  0.960066  0.339211  0.189607
# 21  2014-07-24 03:44:08  0.558115 -0.535687  0.633678 -0.150139 -0.865942
# 22  2014-07-23 22:49:40  0.049894 -0.987885 -0.146950  0.062856 -0.987920
# 23  2014-07-23 22:50:04  0.063673 -0.980138 -0.187816  0.063780 -0.979165
# 24  2014-07-23 23:38:37  0.209461  0.742909  0.635777  0.160667  0.645349
# 25  2014-07-26 02:14:49  0.730976  0.482506  0.482558  0.799915  0.279157
#
#        end_z        lat        lon  \
# 0   0.802321  25.253525   8.005584
# 1   0.604580  25.253525   8.005584
# 2   0.425951  25.253525   8.005584
# 3   0.193601  25.253525   8.005584
# 4   0.110725  25.253525   8.005584
# 5  -0.499187  25.253525   8.005584
# 6   0.689497  50.507339  16.011144
# 7   0.967459  50.507339  16.011144
# 8   0.919045  50.507339  16.011144
# 9   0.980239  50.507445  16.011121
# 10  0.751229  50.507445  16.011121
# 11  0.937117  50.507445  16.011121
# 12  0.754791  50.507445  16.011121
# 13  0.982379  50.507445  16.011121
# 14  0.925910  50.507445  16.011121
# 15  0.892110  50.506834  16.011550
# 16  0.855187  50.506870  16.010832
# 17  0.546458  50.506911  16.010771
# 18  0.907736  50.506870  16.010832
# 19  0.798029  50.506858  16.010803
# 20  0.921404  50.506870  16.010832
# 21  0.477077  25.253525   8.005584
# 22 -0.141641  50.506870  16.010832
# 23 -0.192791  50.506870  16.010832
# 24  0.746801  50.506870  16.010832
# 25  0.531231  50.506870  16.010832
#
#                                          observer  \
# 0    unnamed-298a0e40-8bcd-4210-b129-08eb641b0a97
# 1    unnamed-298a0e40-8bcd-4210-b129-08eb641b0a97
# 2                                          Kaklik
# 3    unnamed-420183ba-a5b9-43e9-b757-769ed7a13599
# 4    unnamed-420183ba-a5b9-43e9-b757-769ed7a13599
# 5                                          Kaklik
# 6                                           Roman
# 7                                           Roman
# 8                                           Roman
# 9                                           Roman
# 10                                          Roman
# 11                                          Roman
# 12                                          Roman
# 13                                          Roman
# 14                                          Roman
# 15                                          MiCHi
# 16                                         Kr3bm4
# 17                                         Kr3bm4
# 18                                         Kr3bm4
# 19                                         Kr3bm4
# 20                                         Kr3bm4
# 21   unnamed-298a0e40-8bcd-4210-b129-08eb641b0a97
# 22                                         Kr3bm4
# 23                                         Kr3bm4
# 24                                         Kr3bm4
# 25                                         Kr3bm4
#
#                              note
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21   Ahoj Ondro. Snad to funguje.
# 22
# 23
# 24
# 25
#
# [26 rows x 11 columns]
