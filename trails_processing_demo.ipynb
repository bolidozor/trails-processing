# %% [markdown]
# Trails processing-demo
# ========================
# Moving your mouse pointer across the display below will rotate the celestial sphere,
# displaying the meteors trails over the stars from Hipparcos catalouge

# %%
# %pylab inline
import sky
import meteors
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', 10000)

# %% [markdown]
# Loading data
# ------------
# Loading data from csv table, fixing the mising observer's position, by using another observer's position (if it exists) or worknig with average position from all observers

# %%
data = meteors.load_data("http://meteor1.astrozor.cz:3003/expa14.csv")
data = meteors.fix_position(data)

# %% [markdown]
# Displaying the meteor trails
# ------------------------
# First argument is pandas data structure, second argument is lowest magnitude shown. Based on [astronomy notebooks by Brandon Rhodes](https://github.com/brandon-rhodes/astronomy-notebooks) You can choose what do you want to display using [standard pandas features](http://pandas.pydata.org/pandas-docs/stable/cookbook.html) (Switch the commented line for an example)

# %%
#sky.starfield(data[data.observer == " Kr3bm4"])
sky.starfield(data, 5)
# Out:
# <style>
#   .constellation {fill: #dddddd}oke
#   .star-blue {fill: #002664}
#   .trails {fill: none; stroke: #000; stroke-width: 1px;}
# </style>
# <script>
# var boundary_data = {'LIB':{'type':'Polygon','coordinates':[[[54300,0.0],[54300,-195.0],[57300,-195.0],[57300,-480.0],[57300,-1200.0],[56400,-1200.0],[56400,-1770.0],[53700,-1770.0],[53700,-1470.0],[51300,-1470.0],[51300,-1320.0],[51300,-480.0],[52800,-480.0],[52800,0.0]]]},'MIC':{'type':'Polygon','coordinates':[[[73200,-1680.0],[76800,-1680.0],[76800,-2220.0],[76800,-2730.0],[73200,-2730.0]]]},'BOO':{'type':'Polygon','coordinates':[[[54300,480.0],[48600,480.0],[48600,900.0],[48600,1710.0],[50250,1710.0],[50250,1845.0],[50520,1845.0],[50520,2910.0],[50520,3330.0],[51900,3330.0],[54900,3330.0],[54900,3180.0],[56700,3180.0],[56700,3090.0],[56700,2400.0],[55560,2400.0],[55560,1980.0],[54660,1980.0],[54660,1560.0],[54300,1560.0]]]},'DRA':{'type':'Polygon','coordinates':[[[33000,4410.0],[33000,4920.0],[38400,4920.0],[38400,4800.0],[41400,4800.0],[41400,4620.0],[46800,4620.0],[46800,4200.0],[50400,4200.0],[50400,3960.0],[56400,3960.0],[56400,4200.0],[59520,4200.0],[59520,4500.0],[63000,4500.0],[63000,4800.0],[64800,4800.0],[64800,5160.0],[75600,5160.0],[75600,4800.0],[72600,4800.0],[72600,4500.0],[74400,4500.0],[74400,4020.0],[73500,4020.0],[73500,3690.0],[72000,3690.0],[72000,3570.0],[71160,3570.0],[71160,3480.0],[69900,3480.0],[69900,3330.0],[68700,3330.0],[68700,2850.0],[65640,2850.0],[65640,3030.0],[61200,3030.0],[61200,3090.0],[56700,3090.0],[56700,3180.0],[54900,3180.0],[54900,3330.0],[51900,3330.0],[51900,3780.0],[48600,3780.0],[48600,3840.0],[43200,3840.0],[43200,3990.0],[40800,3990.0],[40800,4410.0]]]},'TAU':{'type':'Polygon','coordinates':[[[11820,-105.0],[11820,0.0],[11820,595.0],[11820,1140.0],[12120,1140.0],[12120,1840.0],[16200,1840.0],[16200,1800.0],[17100,1800.0],[17100,1710.0],[21180,1710.0],[21180,1680.0],[21180,1370.0],[20520,1370.0],[20520,1080.0],[20760,1080.0],[20760,750.0],[20160,750.0],[20160,930.0],[19200,930.0],[19200,960.0],[17880,960.0],[17880,930.0],[16620,930.0],[16620,0.0],[12900,0.0],[12900,-105.0]]]},'PAV':{'type':'Polygon','coordinates':[[[64800,-4500.0],[64800,-4050.0],[63000,-4050.0],[63000,-3420.0],[64800,-3420.0],[73200,-3420.0],[73200,-3600.0],[76800,-3600.0],[76800,-4500.0]]]},'LYR':{'type':'Polygon','coordinates':[[[67920,1530.0],[67920,1560.0],[66120,1560.0],[66120,1800.0],[65430,1800.0],[65430,2850.0],[65640,2850.0],[68700,2850.0],[69000,2850.0],[69000,2610.0],[69840,2610.0],[69840,2190.0],[69690,2190.0],[69690,1800.0],[69330,1800.0],[69330,1650.0],[69330,1530.0]]]},'PIC':{'type':'Polygon','coordinates':[[[21600,-2580.0],[21600,-3045.0],[21600,-3150.0],[22200,-3150.0],[22200,-3300.0],[23400,-3300.0],[23400,-3480.0],[24600,-3480.0],[24600,-3840.0],[23700,-3840.0],[21600,-3840.0],[21600,-3660.0],[19800,-3660.0],[19800,-3450.0],[18000,-3450.0],[18000,-3240.0],[16200,-3240.0],[16200,-2940.0],[16200,-2790.0],[17400,-2790.0],[17400,-2580.0],[18000,-2580.0]]]},'UMI':{'type':'Polygon','coordinates':[[[46800,4620.0],[48900,4620.0],[48900,4800.0],[52200,4800.0],[52200,5190.0],[28800,5190.0],[28800,5280.0],[82800,5280.0],[82800,5170.0],[75600,5170.0],[75600,5160.0],[64800,5160.0],[64800,4800.0],[63000,4800.0],[63000,4500.0],[59520,4500.0],[59520,4200.0],[56400,4200.0],[56400,3960.0],[50400,3960.0],[50400,4200.0],[46800,4200.0]]]},'LYN':{'type':'Polygon','coordinates':[[[26520,2130.0],[26520,2670.0],[24480,2670.0],[24480,3000.0],[23400,3000.0],[23400,3240.0],[21960,3240.0],[21960,3360.0],[21960,3720.0],[25200,3720.0],[25200,3600.0],[28680,3600.0],[30300,3600.0],[30300,2820.0],[33000,2820.0],[33000,2520.0],[34500,2520.0],[34500,2385.0],[33300,2385.0],[33300,2010.0],[28800,2010.0],[27900,2010.0],[27900,2130.0]]]},'CHA':{'type':'Polygon','coordinates':[[[27600,-4950.0],[27600,-4500.0],[32520,-4500.0],[40500,-4500.0],[49200,-4500.0],[49200,-4950.0]]]},'EQU':{'type':'Polygon','coordinates':[[[75000,120.0],[75000,360.0],[75150,360.0],[75150,710.0],[75780,710.0],[76020,710.0],[76020,750.0],[76800,750.0],[76800,120.0]]]},'PER':{'type':'Polygon','coordinates':[[[9780,1840.0],[9780,2040.0],[9240,2040.0],[9240,22 ...

# %% [markdown]
# Ploting the score board
# -----------------------
# Winner schould get chocolate

# %%
score = data.groupby("observer").observer.count()
score.sort(ascending = False)

font = {'size'   : 18}
matplotlib.rc('font', **font)
rcParams['figure.figsize'] = (18, 5)
score.plot(kind = "bar")

# %% [markdown]
# Table of all records
# --------------------
# Time is in utc

# %%
data
# Out:
#                    time     beg_x     beg_y     beg_z     end_x     end_y  \
# 0   2014-15-07 20:51:03  0.875382  0.409684  0.256643  0.486931  0.762538
# 1   2014-18-07 23:04:14 -0.736155 -0.277478  0.617318 -0.575807  0.794333
# 2   2014-18-07 23:04:25 -0.562187 -0.680422  0.470076 -0.110813 -0.987654
# 3   2014-18-07 23:05:43 -0.585938 -0.660247 -0.469840 -0.208504 -0.841034
# 4   2014-18-07 23:09:38 -0.480081  0.519489  0.706862 -0.568090  0.449296
# 5   2014-18-07 23:09:49 -0.238103  0.026114  0.970889 -0.249532  0.041908
# 6   2014-18-07 23:09:56  0.023791  0.396801  0.917596  0.006202  0.394104
# 7   2014-18-07 23:19:32 -0.119441  0.071627  0.990254 -0.174212  0.093709
# 8   2014-18-07 23:19:39 -0.536367  0.354943  0.765719 -0.555615  0.356295
# 9   2014-18-07 23:19:46  0.091953  0.302379  0.948742  0.046767  0.345869
# 10  2014-18-07 23:20:01 -0.502481  0.541624  0.673911 -0.438543  0.487822
# 11  2014-18-07 23:20:12 -0.044556  0.185240  0.981683 -0.140737  0.122985
# 12  2014-18-07 23:20:22  0.184517  0.284969  0.940609  0.163018  0.340759
# 13  2014-19-07 12:54:19  0.759278 -0.650706 -0.008876 -0.447226  0.064251
# 14  2014-20-07 01:53:11 -0.168897 -0.196156  0.965918 -0.518258 -0.008029
# 15  2014-20-07 01:54:11 -0.323576  0.495756  0.805931 -0.683826  0.483493
# 16  2014-20-07 02:36:33  0.096707  0.110179  0.989196  0.056343  0.415740
# 17  2014-20-07 03:00:18 -0.194946  0.523847  0.829205 -0.520672  0.303398
# 18  2014-20-07 03:00:34  0.246427 -0.132466  0.960066  0.339211  0.189607
# 19  2014-23-07 22:49:40  0.049894 -0.987885 -0.146950  0.062856 -0.987920
# 20  2014-23-07 22:50:04  0.063673 -0.980138 -0.187816  0.063780 -0.979165
# 21  2014-23-07 23:38:37  0.209461  0.742909  0.635777  0.160667  0.645349
# 22  2014-26-07 02:14:49  0.730976  0.482506  0.482558  0.799915  0.279157
#
#        end_z        lat        lon  \
# 0   0.425951  30.304230   9.606701
# 1   0.193601  30.304230   9.606701
# 2   0.110725  30.304230   9.606701
# 3  -0.499187  30.304230   9.606701
# 4   0.689497  50.507339  16.011144
# 5   0.967459  50.507339  16.011144
# 6   0.919045  50.507339  16.011144
# 7   0.980239  50.507445  16.011121
# 8   0.751229  50.507445  16.011121
# 9   0.937117  50.507445  16.011121
# 10  0.754791  50.507445  16.011121
# 11  0.982379  50.507445  16.011121
# 12  0.925910  50.507445  16.011121
# 13  0.892110  50.506834  16.011550
# 14  0.855187  50.506870  16.010832
# 15  0.546458  50.506911  16.010771
# 16  0.907736  50.506870  16.010832
# 17  0.798029  50.506858  16.010803
# 18  0.921404  50.506870  16.010832
# 19 -0.141641  50.506870  16.010832
# 20 -0.192791  50.506870  16.010832
# 21  0.746801  50.506870  16.010832
# 22  0.531231  50.506870  16.010832
#
#                                          observer note
# 0                                          Kaklik  NaN
# 1    unnamed-420183ba-a5b9-43e9-b757-769ed7a13599  NaN
# 2    unnamed-420183ba-a5b9-43e9-b757-769ed7a13599  NaN
# 3                                          Kaklik  NaN
# 4                                           Roman  NaN
# 5                                           Roman  NaN
# 6                                           Roman  NaN
# 7                                           Roman  NaN
# 8                                           Roman  NaN
# 9                                           Roman  NaN
# 10                                          Roman  NaN
# 11                                          Roman  NaN
# 12                                          Roman  NaN
# 13                                          MiCHi  NaN
# 14                                         Kr3bm4  NaN
# 15                                         Kr3bm4  NaN
# 16                                         Kr3bm4  NaN
# 17                                         Kr3bm4  NaN
# 18                                         Kr3bm4  NaN
# 19                                         Kr3bm4
# 20                                         Kr3bm4
# 21                                         Kr3bm4
# 22                                         Kr3bm4
#
# [23 rows x 11 columns]
